# %%
import pandas as pd

# %%
df = pd.read_csv('./data/2022-4-20/WRD/1/live.csv')

# %%
# !ls ./data/2022-4-20
# Out:
# AUB BER CHY IJN LEB M1V MR  PHI SYD TUP WRD
# B9D BUF HAR KEE LFD MMA PEN SOV TAM WFR

# %%
df
# Out:
#     Unnamed: 0                    datetime  \
# 0            0  2022-04-20 10:55:13.913951
# 1            0  2022-04-20 10:55:29.530696
# 2            0  2022-04-20 10:55:43.003550
# 3            0  2022-04-20 10:55:58.485492
# 4            0  2022-04-20 10:56:13.451190
# ..         ...                         ...
# 56           0  2022-04-20 11:12:21.338327
# 57           0  2022-04-20 11:12:36.614330
# 58           0  2022-04-20 11:12:52.412200
# 59           0  2022-04-20 11:13:06.692931
# 60           0  2022-04-20 11:13:24.291758
#
#                                                   bi1  \
# 0   {"odds_numerator": 5, "odds_denominator": null...
# 1   {"odds_numerator": 5, "odds_denominator": null...
# 2   {"odds_numerator": 5, "odds_denominator": null...
# 3   {"odds_numerator": 5, "odds_denominator": null...
# 4   {"odds_numerator": 9, "odds_denominator": 2, "...
# ..                                                ...
# 56  {"odds_numerator": 5, "odds_denominator": null...
# ...
